# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#READING DATA SET

data = pd.read_csv("Dataset_01_standarized_.csv")
# data = pd.read_csv("Dataset_01_non_standarized_.csv")

# %%
#data.info()

# %%
#  13.0 = Snack Food, 4.0 =  Diary, 1.0 = bread and meat=10.0

from pandas.plotting import scatter_matrix
features_mean=['Item_Weight','Item_Fat_Content','Item_Visibility','Item_Type'
             ,'Item_MRP','Outlet_Establishment_Year','Outlet_Size','Outlet_Location_Type','Outlet_Type'
             ]
color_dic = {'M':'red', 'B':'blue'}
colors = data['Outlet_Type'].map(lambda x: color_dic.get(x))

sm = scatter_matrix(data[features_mean], c=colors, alpha=0.4, figsize=((15,15)));

plt.show()

# x=data['Item_Weight']
# y=data['Item_Fat_Content']
# y=data['Item_Visibility']
# y=data['Item_Type']
# y=data['Item_MRP']
# y=data['Outlet_Establishment_Year']
# y=data['Outlet_Size']
# y=data['Outlet_Location_Type']
# y=data['Outlet_Type']

# y=data['Item_Weight']
# y=data['Item_Fat_Content']
# y=data['Item_Visibility']
# x=data['Item_Type']
# y=data['Item_MRP']
# y=data['Outlet_Establishment_Year']
# y=data['Outlet_Size']
# y=data['Outlet_Location_Type']
# y=data['Outlet_Type']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4290             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4291                 colors = mcolors.to_rgba_array(c)
#    4292             except (TypeError, ValueError) as err:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     340     else:
# --> 341         return np.array([to_rgba(cc, alpha) for cc in c])
#     342
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in <listcomp>(.0)
#     340     else:
# --> 341         return np.array([to_rgba(cc, alpha) for cc in c])
#     342
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
# ...

# %%
#Since 



plt.scatter(x, y,s=50, c=["b"]) 
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)), color='yellow')
# plt.show()
plt.title('A plot to show the correlation  between Item_Weight and Item_Fat_Content')
plt.xlabel('Item_Weight')
plt.ylabel('Item_Fat_Content')
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-94-eaf224a0b715> in <module>
#       4
#       5 plt.scatter(x, y,s=50, c=["b"])
# ----> 6 plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)), color='yellow')
#       7 # plt.show()
#       8 plt.title('A plot to show the correlation  between Item_Weight and Item_Fat_Content')
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     627     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     628     lhs /= scale
# --> 629     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     630     c = (c.T/scale).T  # broadcast scale coefficients
#     631
#
# <__array_function__ internals> in lstsq(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in lstsq(a, b, rcond)
# ...
